# %%
library(readxl)
library(IRdisplay)

# Variables
todays_date <- format(Sys.Date(), "%Y-%m-%d")
student_id <- "edwgol5635"

# Read the Excel file
file_path <- "C:/Files/Excel/DA_PythonR/2019_Happiness_Index_v2_Task2.xlsx"
df_new <- read_excel(file_path)

# Header
display_markdown(paste("###", student_id, "-", todays_date))

# ---- Descriptive Statistics ----

# Mean Happiness Score
mean_happiness_score <- mean(df_new$Score, na.rm = TRUE)

# Standard Deviation
std_happiness_score <- sd(df_new$Score, na.rm = TRUE)

# Median
median_happiness_score <- median(df_new$Score, na.rm = TRUE)

# Correlation with Life Expectancy
correlation_happiness_life_expectancy <- cor(
  df_new$Score,
  df_new$`Healthy life expectancy`,
  use = "pairwise.complete.obs"
)

# Min and Max
min_happiness_score <- min(df_new$Score, na.rm = TRUE)
max_happiness_score <- max(df_new$Score, na.rm = TRUE)

# 25th Percentile of Freedom Scores
freedom_25th_percentile <- quantile(
  df_new$`Freedom to make life choices`,
  0.25,
  na.rm = TRUE
)

# ---- Display Results ----
display_markdown("### Descriptive Statistics")

print(paste("Mean Happiness Score:", mean_happiness_score))
print(paste("Standard Deviation of Happiness Score:", std_happiness_score))
print(paste("Median Happiness Score:", median_happiness_score))
print(paste("Correlation between Happiness Score and Life Expectancy:",
            correlation_happiness_life_expectancy))
print(paste("Minimum Happiness Score:", min_happiness_score))
print(paste("Maximum Happiness Score:", max_happiness_score))
print(paste("25th Percentile of Freedom Scores:", freedom_25th_percentile))
# Out:
# ### edwgol5635 - 2026-02-05
# ### Descriptive Statistics
# [1] "Mean Happiness Score: 5.40709615384615"
# [1] "Standard Deviation of Happiness Score: 1.11311986879567"
# [1] "Median Happiness Score: 5.3795"
# [1] "Correlation between Happiness Score and Life Expectancy: 0.779883149242583"
# [1] "Minimum Happiness Score: 2.853"
# [1] "Maximum Happiness Score: 7.769"
# [1] "25th Percentile of Freedom Scores: 0.308"

# %%
library(readxl)     # Read Excel files
library(ggplot2)    # Visualization
library(dplyr)      # Data manipulation
library(corrplot)   # Correlation matrix visualization

# Variables
student_id <- "edwgol5635"

# Read the Excel file
file_path <- "C:/Files/Excel/DA_PythonR/2019_Happiness_Index_v2_Task2.xlsx"
df_new <- read_excel(file_path)

# Current date/time
current_datetime <- format(Sys.time(), "%Y-%m-%d %H:%M:%S")

# Histogram: Number of Countries vs Happiness Score
ggplot(df_new, aes(x = Score)) +
  geom_histogram(binwidth = 0.2, fill = "skyblue", color = "black") +
  xlab("Happiness Score") +
  ylab("Number of Countries") +
  ggtitle(
    paste(
      "Histogram of Number of Countries vs Happiness Score - Student ID:",
      student_id, "-", current_datetime
    )
  ) +
  theme_minimal() +
  theme(
    panel.grid.major = element_line(colour = "grey"),
    plot.title = element_text(face = "bold")
  )
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# corrplot 0.95 loaded
# plot without title

# %%
install.packages("corrplot")
# Out:
# Warning message:
# "package 'corrplot' is in use and will not be installed"

# %%
library(readxl)     # Read Excel files
library(ggplot2)    # Visualization
library(dplyr)      # Data manipulation
library(corrplot)   # Correlation matrix visualization

# Variables
student_id <- "edwgol5635"

# Read the Excel file
file_path <- "C:/Files/Excel/DA_PythonR/2019_Happiness_Index_v2_Task2.xlsx"
df_new <- read_excel(file_path)

# Current date/time
current_datetime <- format(Sys.time(), "%Y-%m-%d %H:%M:%S")

# Histogram: Number of Countries vs Happiness Score
ggplot(df_new, aes(x = Score)) +
  geom_histogram(binwidth = 0.2, fill = "skyblue", color = "black") +
  xlab("Happiness Score") +
  ylab("Number of Countries") +
  ggtitle(
    paste(
      "Histogram of Number of Countries vs Happiness Score - Student ID:",
      student_id, "-", current_datetime
    )
  ) +
  theme_minimal() +
  theme(
    panel.grid.major = element_line(colour = "grey"),
    plot.title = element_text(face = "bold")
  )
# Out:
# plot without title

# %%
# Variables
student_id <- "edwgol5635"

# Read the Excel file
file_path <- "C:/Files/Excel/DA_PythonR/2019_Happiness_Index_v2_Task2.xlsx"
df_new <- read_excel(file_path)

# Current date/time
current_datetime <- format(Sys.time(), "%Y-%m-%d %H:%M:%S")

# Select Top 10 Countries by Happiness Score
top_10_countries <- df_new %>%
  arrange(desc(Score)) %>%
  head(10)

# Bar Chart for Top 10 Countries by Happiness Score
ggplot(top_10_countries,
       aes(x = reorder(`Country or region`, -Score), y = Score)) +
  geom_bar(stat = "identity", fill = "green") +
  xlab("Country") +
  ylab("Happiness Score") +
  ggtitle(
    paste(
      "Top 10 Countries by Happiness Score - Student ID:",
      student_id, "-", current_datetime
    )
  ) +
  coord_flip() +
  theme_minimal() +
  theme(
    panel.grid.major = element_line(colour = "grey"),
    plot.title = element_text(face = "bold")
  )
# Out:
# plot without title

# %%
# Variables
student_id <- "edwgol5635"

# Read the Excel file
file_path <- "C:/Files/Excel/DA_PythonR/2019_Happiness_Index_v2_Task2.xlsx"
df_new <- read_excel(file_path)

# Current date/time
current_datetime <- format(Sys.time(), "%Y-%m-%d %H:%M:%S")

# Scatter plot with trendline
ggplot(df_new, aes(x = `GDP per capita`, y = Score)) +
  geom_point(aes(color = "Data Points"), size = 3) +
  geom_smooth(method = "lm", se = FALSE, aes(color = "Trendline")) +
  scale_color_manual(
    values = c("Data Points" = "blue", "Trendline" = "red")
  ) +
  xlab("GDP per Capita") +
  ylab("Happiness Score") +
  ggtitle(
    paste(
      "Happiness Score vs GDP per Capita with Trendline - Student ID:",
      student_id, "-", current_datetime
    )
  ) +
  theme_minimal() +
  theme(
    panel.grid.major = element_line(colour = "grey"),
    legend.title = element_blank(),
    plot.title = element_text(face = "bold")
  )
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Variables
student_id <- "edwgol5635"

# Read the Excel file
file_path <- "C:/Files/Excel/DA_PythonR/2019_Happiness_Index_v2_Task2.xlsx"
df_new <- read_excel(file_path)

# Current date/time
current_datetime <- format(Sys.time(), "%Y-%m-%d %H:%M:%S")

# Select Columns for Correlation Matrix
selected_columns <- df_new %>%
  select(
    Score,
    `GDP per capita`,
    `Social support`,
    Generosity
  )

# Calculate Correlation Matrix
correlation_matrix <- cor(
  selected_columns,
  use = "pairwise.complete.obs"
)

# Create Heatmap
corrplot(
  correlation_matrix,
  method = "color",
  type = "upper",
  title = paste(
    "Heatmap of Correlations - Student ID:",
    student_id, "-", current_datetime
  ),
  tl.col = "black",
  tl.srt = 45,
  number.cex = 0.7,
  addCoef.col = "black"
)
# Out:
# Plot with title "Heatmap of Correlations - Student ID: edwgol5635 - 2026-02-05 14:06:30"
